# %%
import arxiv
from arxiv import Result

# Construct the default API client.
client = arxiv.Client(
    page_size=100,
    delay_seconds=0.1,
    num_retries=3,
)

# Search for the 10 most recent articles matching the keyword "quantum."
search = arxiv.Search(
  query = "quantum",
  max_results = 10,
  sort_by = arxiv.SortCriterion.SubmittedDate
)

results = client.results(search)

# %%
all_results = list(results)
result_entry:Result = all_results[0]
result_entry
# Out:
# arxiv.Result(entry_id='http://arxiv.org/abs/2503.20778v1', updated=datetime.datetime(2025, 3, 26, 17, 56, 38, tzinfo=datetime.timezone.utc), published=datetime.datetime(2025, 3, 26, 17, 56, 38, tzinfo=datetime.timezone.utc), title='Detectability of the chiral gravitational wave background from audible axions with the LISA-Taiji network', authors=[arxiv.Result.Author('Hong Su'), arxiv.Result.Author('Baoyu Xu'), arxiv.Result.Author('Ju Chen'), arxiv.Result.Author('Chang Liu'), arxiv.Result.Author('Yun-Long Zhang')], summary='The chiral gravitational wave background (GWB) can be produced by axion-like\nfields in the early universe. We perform parameter estimation for two types of\nchiral GWB with the LISA-Taiji network: axion-dark photon coupling and\naxion-Nieh-Yan coupling. We estimate the spectral parameters of these two\nmechanisms induced by axion and determine the normalized model parameters using\nthe Fisher information matrix. For highly chiral GWB signals that we choose to\nanalyze in the mHz band, the normalized model parameters are constrained with a\nrelative error less than $6.7\\%$ (dark photon coupling) and $2.2\\%$ (Nieh-Yan\ncoupling) at the one-sigma confidence level. The circular polarization\nparameters are constrained with a relative error around $21\\%$ (dark photon\ncoupling) and $6.2\\%$ (Nieh-Yan coupling) at the one-sigma confidence level.', comment='15 pages, 10 figures', journal_ref=None, doi=None, primary_category='astro-ph.CO', categories=['astro-ph.CO', 'gr-qc', 'hep-ph'], links=[arxiv.Result.Link('http://arxiv.org/abs/2503.20778v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2503.20778v1', title='pdf', rel='related', content_type=None)])

# %%
result_entry.__dict__
# Out:
# {'entry_id': 'http://arxiv.org/abs/2503.20778v1',
#  'updated': datetime.datetime(2025, 3, 26, 17, 56, 38, tzinfo=datetime.timezone.utc),
#  'published': datetime.datetime(2025, 3, 26, 17, 56, 38, tzinfo=datetime.timezone.utc),
#  'title': 'Detectability of the chiral gravitational wave background from audible axions with the LISA-Taiji network',
#  'authors': [arxiv.Result.Author('Hong Su'),
#   arxiv.Result.Author('Baoyu Xu'),
#   arxiv.Result.Author('Ju Chen'),
#   arxiv.Result.Author('Chang Liu'),
#   arxiv.Result.Author('Yun-Long Zhang')],
#  'summary': 'The chiral gravitational wave background (GWB) can be produced by axion-like\nfields in the early universe. We perform parameter estimation for two types of\nchiral GWB with the LISA-Taiji network: axion-dark photon coupling and\naxion-Nieh-Yan coupling. We estimate the spectral parameters of these two\nmechanisms induced by axion and determine the normalized model parameters using\nthe Fisher information matrix. For highly chiral GWB signals that we choose to\nanalyze in the mHz band, the normalized model parameters are constrained with a\nrelative error less than $6.7\\%$ (dark photon coupling) and $2.2\\%$ (Nieh-Yan\ncoupling) at the one-sigma confidence level. The circular polarization\nparameters are constrained with a relative error around $21\\%$ (dark photon\ncoupling) and $6.2\\%$ (Nieh-Yan coupling) at the one-sigma confidence level.',
#  'comment': '15 pages, 10 figures',
#  'journal_ref': None,
#  'doi': None,
#  'primary_category': 'astro-ph.CO',
#  'categories': ['astro-ph.CO', 'gr-qc', 'hep-ph'],
#  'links': [arxiv.Result.Link('http://arxiv.org/abs/2503.20778v1', title=None, rel='alternate', content_type=None),
#   arxiv.Result.Link('http://arxiv.org/pdf/2503.20778v1', title='pdf', rel='related', content_type=None)],
#  'pdf_url': 'http://arxiv.org/pdf/2503.20778v1',
#  '_raw': {'id': 'http://arxiv.org/abs/2503.20778v1',
#   'guidislink': True,
#   'link': 'http://arxiv.org/abs/2503.20778v1',
#   'updated': '2025-03-26T17:56:38Z',
#   'updated_parsed': time.struct_time(tm_year=2025, tm_mon=3, tm_mday=26, tm_hour=17, tm_min=56, tm_sec=38, tm_wday=2, tm_yday=85, tm_isdst=0),
#   'published': '2025-03-26T17:56:38Z',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=3, tm_mday=26, tm_hour=17, tm_min=56, tm_sec=38, tm_wday=2, tm_yday=85, tm_isdst=0),
#   'title': 'Detectability of the chiral gravitational wave background from audible\n  axions with the LISA-Taiji network',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': 'Detectability of the chiral gravitational wave background from audible\n  axions with the LISA-Taiji network'},
#   'summary': 'The chiral gravitational wave background (GWB) can be produced by axion-like\nfields in the early universe. We perform parameter estimation for two types of\nchiral GWB with the LISA-Taiji network: axion-dark photon coupling and\naxion-Nieh-Yan coupling. We estimate the spectral parameters of these two\nmechanisms induced by axion and determine the normalized model parameters using\nthe Fisher information matrix. For highly chiral GWB signals that we choose to\nanalyze in the mHz band, the normalized model parameters are constrained with a\nrelative error less than $6.7\\%$ (dark photon coupling) and $2.2\\%$ (Nieh-Yan\ncoupling) at the one-sigma confidence level. The circular polarization\nparameters are constrained with a relative error around $21\\%$ (dark photon\ncoupling) and $6.2\\%$ (Nieh-Yan coupling) at the one-sigma confidence level.',
#   'summary_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': 'The chiral gravitational wave background (GWB) can be produced by axion-like\nfields in the early universe. We perform parameter estimation for two types of\nchiral GWB with the LISA-Taiji network: axion-dark photon coupling and\naxion-Nieh-Yan coupling. We estimate the spectral parameters of these two\nmechanisms induced by axion and determine the normalized model parameters using\nthe Fisher information matrix. For highly chiral GWB signals that we choose to\nanalyze in the mHz band, the normalized model parameters are constrained with a\nrelative error less than $6.7\\%$ (dark photon coupling) and $2.2\\%$ (Nieh-Yan\ncoupling) at the one-sigma confidence level. The circular polarization\nparameters are constrained with a relative error around $21\\%$ (dark photon\ncoupling) and $6.2\\%$ (Nieh-Yan coupling) at the one-sigma confidence level.'},
#   'authors': [{'name': 'Hong Su'},
#    {'name': 'Baoyu Xu'},
#    {'name': 'Ju Chen'},
#    {'name': 'Chang Liu'},
#    {'name': 'Yun-Long Zhang'}],
#   'author_detail': {'name': 'Yun-Long Zhang'},
#   'author': 'Yun-Long Zhang',
#   'arxiv_comment': '15 pages, 10 figures',
#   'links': [{'href': 'http://arxiv.org/abs/2503.20778v1',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'title': 'pdf',
#     'href': 'http://arxiv.org/pdf/2503.20778v1',
#     'rel': 'related',
#     'type': 'application/pdf'}],
#   'arxiv_primary_category': {'term': 'astro-ph.CO',
#    'scheme': 'http://arxiv.org/schemas/atom'},
#   'tags': [{'term': 'astro-ph.CO',
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'label': None},
#    {'term': 'gr-qc', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None},
#    {'term': 'hep-ph',
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'label': None}]}}

# %%
import os
download_dir = './arxiv_downloads'
if not os.path.exists(download_dir):
    os.mkdir(download_dir)

# %%
result_entry._get_default_filename()
# Out:
# '2503.20778v1.Detectability_of_the_chiral_gravitational_wave_background_from_audible_axions_with_the_LISA_Taiji_network.pdf'

# %%
result_entry.download_pdf(dirpath=download_dir)
# Out:
# './arxiv_downloads\\2503.20778v1.Detectability_of_the_chiral_gravitational_wave_background_from_audible_axions_with_the_LISA_Taiji_network.pdf'

# %%
result_entry.download_source(dirpath=download_dir)
# Out:
# './arxiv_downloads\\2503.20778v1.Detectability_of_the_chiral_gravitational_wave_background_from_audible_axions_with_the_LISA_Taiji_network.tar.gz'

# %% [markdown]
# ---
# # Actually Download

# %%
def download_if_new(result:Result):
    filename = result._get_default_filename()
    filepath = os.path.join(download_dir, filename)
    if os.path.exists(filepath):
        return False
    
    try:
        result.download_pdf(dirpath=download_dir)
    except Exception as e:
        print(f"Error downloading {filename}: {e}")
        return False
    return filepath

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import tqdm


class BulkDownloader:
    def __init__(self, threads: int = 10):
        self.thread_pool: ThreadPoolExecutor = ThreadPoolExecutor(threads)

    def download_all_parallel(self, search: arxiv.Search):
        client = arxiv.Client(
            page_size=100,
            delay_seconds=0.0,
            num_retries=3,
        )
        results = client.results(search)

        futures = [
            self.thread_pool.submit(download_if_new, result) for result in results
        ]
        for future in tqdm.tqdm(as_completed(futures), total=len(futures)):
            print(f"Downloaded {future.result()}")

        print("All downloads completed.")

# %%
downloader = BulkDownloader(threads=10)

# %%
categories = [
    # https://arxiv.org/help/api/user-manual#query_details
    "cs.AI", # Artificial Intelligence, 
    "cs.CL", # Computation and Language
    "cs.LG", # Machine Learning,
    "stat.ML", # Machine Learning,
    "cs.CV", # Computer Vision and Pattern Recognition,
    "cs.MA", # Multiagent Systems,
    "cs.NE", # Neural and Evolutionary Computing,
]

search = arxiv.Search(
  query = ' OR '.join(categories),
  max_results = 500,
  sort_by = arxiv.SortCriterion.Relevance,
)

# %%
downloader.download_all_parallel(search)
# Out:
# Error downloading 1805.08180v2.Hierarchical_Reinforcement_Learning_with_Hindsight.pdf: HTTP Error 404: Not Found
# Error downloading 1903.02172v1.AAAI_2019_Workshop_on_Games_and_Simulations_for_Artificial_Intelligence.pdf: HTTP Error 404: Not Found
#   0%|          | 0/500 [00:00<?, ?it/s]
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\
pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2211.08407v4.Trust_Awareness_to_Secure_Swarm_Intelligence_from_Data_Injection_Attack.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1701.01329v1.Generating_Focussed_Molecule_Libraries_for_Drug_Discovery_with_Recurrent_Neural_Networks.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1808.00260v1.A_Review_on_the_Application_of_Natural_Computing_in_Environmental_Informatics.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2110.12894v2.The_Efficiency_Misnomer.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2411.02820v3.DroidSpeak__KV_Cache_Sharing_for_Cross_LLM_Communication_and_Multi_LLM_Serving.pdf
# Downloaded ./arxiv_downloads\2405.11106v1.LLM_based_Multi_Agent_Reinforcement_Learning__Current_and_Future_Directions.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1709.06990v1.Text_Compression_for_Sentiment_Analysis_via_Evolutionary_Algorithms.pdf
# Downloaded ./arxiv_downloads\1509.08634v1.Learning_dynamic_Boltzmann_machines_with_spike_timing_dependent_plasticity.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2103.01636v1.Sparse_Training_Theory_for_Scalable_and_Efficient_Agents.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1705.06273v1.Transfer_Learning_for_Named_Entity_Recognition_with_Neural_Networks.pdf
# Downloaded ./arxiv_downloads\1805.12024v1.Privacy_Aware_Offloading_of_Deep_Neural_Networks.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\2412.03624v1.How_to_Correctly_do_Semantic_Backpropagation_on_Language_based_Agentic_Systems.pdf
# Downloaded ./arxiv_downloads\1103.4487v1.Handwritten_Digit_Recognition_with_a_Committee_of_Deep_Neural_Nets_on_GPUs.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2106.07847v4.Learning_Stable_Classifiers_by_Transferring_Unstable_Features.pdf
# Downloaded ./arxiv_downloads\2403.15464v1.LLMs_based_Few_Shot_Disease_Predictions_using_EHR__A_Novel_Approach_Combining_Predictive_Agent_Reasoning_and_Critical_Agent_Instruction.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1606.03864v2.Neural_Associative_Memory_for_Dual_Sequence_Modeling.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2305.17066v1.Mindstorms_in_Natural_Language_Based_Societies_of_Mind.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2006.14032v2.Compositional_Explanations_of_Neurons.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\2003.06212v1.Accelerating_and_Improving_AlphaZero_Using_Population_Based_Training.pdf
# Downloaded ./arxiv_downloads\2110.14182v1.Evidential_Softmax_for_Sparse_Multimodal_Distributions_in_Deep_Generative_Models.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1604.04562v3.A_Network_based_End_to_End_Trainable_Task_oriented_Dialogue_System.pdf
# Downloaded ./arxiv_downloads\1903.02079v1.Optimizing_Software_Effort_Estimation_Models_Using_Firefly_Algorithm.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1810.01406v1.Super_Resolution_via_Conditional_Implicit_Maximum_Likelihood_Estimation.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1510.08983v2.Highway_Long_Short_Term_Memory_RNNs_for_Distant_Speech_Recognition.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\2502.07373v1.EvoFlow__Evolving_Diverse_Agentic_Workflows_On_The_Fly.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2310.02168v4.Editing_Personality_for_Large_Language_Models.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2209.03942v1.Data_Feedback_Loops__Model_driven_Amplification_of_Dataset_Biases.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1903.10545v5.Winning_Isn_t_Everything__Enhancing_Game_Development_with_Intelligent_Agents.pdf
# Downloaded ./arxiv_downloads\1602.06662v2.Recurrent_Orthogonal_Networks_and_Long_Memory_Tasks.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1709.07224v2.Local_Communication_Protocols_for_Learning_Complex_Swarm_Behaviors_with_Deep_Reinforcement_Learning.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1905.04926v1.Differentiable_Game_Mechanics.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1511.08400v7.Regularizing_RNNs_by_Stabilizing_Activations.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2004.01097v2.Learning_to_cooperate__Emergent_communication_in_multi_agent_navigation.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1808.04359v2.Community_Regularization_of_Visually_Grounded_Dialog.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2109.09371v1.Learning_Natural_Language_Generation_from_Scratch.pdf
# Downloaded ./arxiv_downloads\2007.02382v2.Decentralized_Reinforcement_Learning__Global_Decision_Making_via_Local_Economic_Transactions.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1503.06410v2.What_the_F_measure_doesn_t_measure__Features__Flaws__Fallacies_and_Fixes.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1906.01983v1.The_Computational_Structure_of_Unintentional_Meaning.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1909.10476v1.Research_Directions_in_Democratizing_Innovation_through_Design_Automation__One_Click_Manufacturing_Services_and_Intelligent_Machines.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1805.10255v1.Parallel_Architecture_and_Hyperparameter_Search_via_Successive_Halving_and_Classification.pdf
# Downloaded ./arxiv_downloads\1502.08029v5.Describing_Videos_by_Exploiting_Temporal_Structure.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2502.04249v1.Free_Energy_Risk_Metrics_for_Systemically_Safe_AI__Gatekeeping_Multi_Agent_Study.pdf
# Downloaded ./arxiv_downloads\2105.01029v2.Initialization_and_Regularization_of_Factorized_Neural_Layers.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1706.07206v2.Explaining_Recurrent_Neural_Network_Predictions_in_Sentiment_Analysis.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2305.02499v1.AutoML_GPT__Automatic_Machine_Learning_with_GPT.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1806.05337v2.Hierarchical_interpretations_for_neural_network_predictions.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2305.00350v1.POUF__Prompt_oriented_unsupervised_fine_tuning_for_large_pre_trained_models.pdf
# Downloaded ./arxiv_downloads\2306.10640v2.Evolving_Strategies_for_Competitive_Multi_Agent_Search.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2310.05976v1.An_evolutionary_model_of_personality_traits_related_to_cooperative_behavior_using_a_large_language_model.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2406.08929v2.Step_by_Step_Diffusion__An_Elementary_Tutorial.pdf
# Downloaded ./arxiv_downloads\2406.13781v1.A_Primal_Dual_Framework_for_Transformers_and_Neural_Networks.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2411.05820v1.Guiding_Genetic_Programming_with_Graph_Neural_Networks.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\1911.04870v1.Network_Classifiers_With_Output_Smoothing.pdf
# Downloaded ./arxiv_downloads\1903.10145v3.Cyclical_Annealing_Schedule__A_Simple_Approach_to_Mitigating_KL_Vanishing.pdf
# Downloaded ./arxiv_downloads\2110.03861v3.QTN_VQC__An_End_to_End_Learning_framework_for_Quantum_Neural_Networks.pdf
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\2106.04258v3.Interpretable_agent_communication_from_scratch__with_a_generic_visual_processor_emerging_on_the_side_.pdf
# Downloaded False
# Downloaded False
# Downloaded ./arxiv_downloads\1706.03946v1.A_Supervised_Approach_to_Extractive_Summarisation_of_Scientific_Papers.pdf
# Downloaded False
# Downloaded ./arxiv_downloads\2110.05422v1.Calibrate_your_listeners__Robust_communication_based_training_for_pragmatic_speakers.pdf
# Downloaded ./arxiv_downloads\1612.02695v1.Towards_better_decoding_and_language_model_integration_in_sequence_to_sequence_models.pdf
# Downloaded ./arxiv_downloads\1611.06791v1.Generalized_Dropout.pdf
# Downloaded False
# Downloaded False
# Downloaded False
Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\2006.00587v5.Towards_Understanding_Cooperative_Multi_Agent_Q_Learning_with_Value_Factorization.pdf
# Downloaded ./arxiv_downloads\1910.01465v2.Reducing_Overestimation_Bias_in_Multi_Agent_Domains_Using_Double_Centralized_Critics.pdf
# Downloaded ./arxiv_downloads\1910.14472v1.Learning_Fairness_in_Multi_Agent_Systems.pdf
# Downloaded ./arxiv_downloads\2006.04037v1.Reinforcement_Learning_for_Multi_Product_Multi_Node_Inventory_Management_in_Supply_Chains.pdf
# Downloaded ./arxiv_downloads\1909.07528v2.Emergent_Tool_Use_From_Multi_Agent_Autocurricula.pdf
# Downloaded ./arxiv_downloads\2003.08353v2.A_Deep_Multi_Agent_Reinforcement_Learning_Approach_to_Autonomous_Separation_Assurance.pdf
# Downloaded ./arxiv_downloads\1905.12127v3.Coordinated_Exploration_via_Intrinsic_Rewards_for_Multi_Agent_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\1905.05408v1.QTRAN__Learning_to_Factorize_with_Transformation_for_Cooperative_Multi_Agent_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\2008.01062v3.QPLEX__Duplex_Dueling_Multi_Agent_Q_Learning.pdf
# Downloaded ./arxiv_downloads\2006.03553v2.Logical_Team_Q_learning__An_approach_towards_factored_policies_in_cooperative_MARL.pdf
# Error downloading 2009.13051v3.Agent_Environment_Cycle_Games.pdf: HTTP Error 404: Not Found
# Downloaded False
# Downloaded ./arxiv_downloads\2102.10362v3.Factored_Policy_Gradients__Leveraging_Structure_for_Efficient_Learning_in_MOMDPs.pdf
# Downloaded ./arxiv_downloads\2111.14375v1.Final_Adaptation_Reinforcement_Learning_for_N_Player_Games.pdf
# Downloaded ./arxiv_downloads\2006.05842v2.The_Emergence_of_Individuality.pdf
# Downloaded ./arxiv_downloads\2212.06279v1.Decentralized_Stochastic_Multi_Player_Multi_Armed_Walking_Bandits.pdf
# Downloaded ./arxiv_downloads\1908.02138v1.Robby_is_Not_a_Robber__anymore___On_the_Use_of_Institutions_for_Learning_Normative_Behavior.pdf
# Downloaded ./arxiv_downloads\2402.01111v1.Near_Optimal_Reinforcement_Learning_with_Self_Play_under_Adaptivity_Constraints.pdf
# Downloaded ./arxiv_downloads\1908.03963v4.A_Review_of_Cooperative_Multi_Agent_Deep_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\2302.02571v1.Offline_Learning_in_Markov_Games_with_General_Function_Approximation.pdf
# Downloaded ./arxiv_downloads\1908.01022v4.Health_Informed_Policy_Gradients_for_Multi_Agent_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\1912.00949v1.Multi_Agent_Deep_Reinforcement_Learning_with_Adaptive_Policies.pdf
# Downloaded ./arxiv_downloads\2302.11793v2.Revisiting_the_Gumbel_Softmax_in_MADDPG.pdf
# Downloaded ./arxiv_downloads\2404.07559v1.Differentially_Private_Reinforcement_Learning_with_Self_Play.pdf
# Downloaded ./arxiv_downloads\2503.09309v1.Steering_No_Regret_Agents_in_MFGs_under_Model_Uncertainty.pdf
# Downloaded ./arxiv_downloads\2001.10468v1.Incorporating_Joint_Embeddings_into_Goal_Oriented_Dialogues_with_Multi_Task_Learning.pdf
# Downloaded ./arxiv_downloads\1910.03492v1.Neural_Language_Priors.pdf
# Downloaded ./arxiv_downloads\2407.10207v3.Learning_to_Steer_Markovian_Agents_under_Model_Uncertainty.pdf
# Downloaded ./arxiv_downloads\1406.1078v3.Learning_Phrase_Representations_using_RNN_Encoder_Decoder_for_Statistical_Machine_Translation.pdf
# Downloaded ./arxiv_downloads\2402.08156v7.Differentially_Private_Distributed_Inference.pdf
# Downloaded ./arxiv_downloads\2006.16823v1.Technical_Report__Auxiliary_Tuning_and_its_Application_to_Conditional_Text_Generation.pdf
# Downloaded ./arxiv_downloads\1909.12557v2.Multi_Agent_Actor_Critic_with_Hierarchical_Graph_Attention_Network.pdf
# Downloaded ./arxiv_downloads\1507.06947v1.Fast_and_Accurate_Recurrent_Neural_Network_Acoustic_Models_for_Speech_Recognition.pdf
# Downloaded ./arxiv_downloads\1603.09643v4.Multi_task_Recurrent_Model_for_Speech_and_Speaker_Recognition.pdf
# Downloaded ./arxiv_downloads\1909.03569v1.Neural_Gaussian_Copula_for_Variational_Autoencoder.pdf
# Downloaded ./arxiv_downloads\1603.01913v2.A_Latent_Variable_Recurrent_Neural_Network_for_Discourse_Relation_Language_Models.pdf
# Downloaded ./arxiv_downloads\2302.06675v4.Symbolic_Discovery_of_Optimization_Algorithms.pdf
# Downloaded ./arxiv_downloads\1606.02960v2.Sequence_to_Sequence_Learning_as_Beam_Search_Optimization.pdf
# Downloaded ./arxiv_downloads\1409.1257v2.Overcoming_the_Curse_of_Sentence_Length_for_Neural_Machine_Translation_using_Automatic_Segmentation.pdf
# Downloaded ./arxiv_downloads\1508.01211v2.Listen__Attend_and_Spell.pdf
# Downloaded ./arxiv_downloads\1805.07443v1.Multi_view_Sentence_Representation_Learning.pdf
# Downloaded ./arxiv_downloads\1805.07475v3.Learning_to_Repair_Software_Vulnerabilities_with_Generative_Adversarial_Networks.pdf
# Downloaded ./arxiv_downloads\1706.02776v1.Optimizing_expected_word_error_rate_via_sampling_for_speech_recognition.pdf
# Downloaded ./arxiv_downloads\1506.07503v1.Attention_Based_Models_for_Speech_Recognition.pdf
#  80%|████████  | 401/500 [00:16<00:05, 19.64it/s]
# Downloaded ./arxiv_downloads\1812.10549v1.Automatic_Summarization_of_Natural_Language.pdf
# Downloaded ./arxiv_downloads\1704.08424v2.Multimodal_Word_Distributions.pdf
# Downloaded ./arxiv_downloads\2001.09977v3.Towards_a_Human_like_Open_Domain_Chatbot.pdf
# Downloaded ./arxiv_downloads\1603.00810v3.Character_based_Neural_Machine_Translation.pdf
# Downloaded ./arxiv_downloads\2502.01384v1.Fine_Tuning_Discrete_Diffusion_Models_with_Policy_Gradient_Methods.pdf
#  81%|████████  | 404/500 [00:16<00:04, 19.26it/s]
# Downloaded ./arxiv_downloads\1709.06011v1.Guided_Deep_Reinforcement_Learning_for_Swarm_Systems.pdf
# Downloaded ./arxiv_downloads\1705.10229v1.Latent_Intention_Dialogue_Models.pdf
# Downloaded ./arxiv_downloads\1611.00454v1.Collaborative_Recurrent_Autoencoder__Recommend_while_Learning_to_Fill_in_the_Blanks.pdf
# Downloaded ./arxiv_downloads\1611.00448v1.Natural_Parameter_Networks__A_Class_of_Probabilistic_Neural_Networks.pdf
# Downloaded ./arxiv_downloads\2211.02403v1.The_Path_to_Autonomous_Learners.pdf
# Downloaded ./arxiv_downloads\1606.07298v1.Explaining_Predictions_of_Non_Linear_Classifiers_in_NLP.pdf
# Downloaded ./arxiv_downloads\2006.01112v2.Cascaded_Text_Generation_with_Markov_Transformers.pdf
# Downloaded ./arxiv_downloads\1807.06613v3.Deep_Reinforcement_Learning_for_Swarm_Systems.pdf
# Downloaded ./arxiv_downloads\2406.13762v2.Unveiling_the_Hidden_Structure_of_Self_Attention_via_Kernel_Principal_Component_Analysis.pdf
# Downloaded ./arxiv_downloads\1909.10470v2.Improving_Generative_Visual_Dialog_by_Answering_Diverse_Questions.pdf
# Downloaded ./arxiv_downloads\2405.14522v1.Explaining_Black_box_Model_Predictions_via_Two_level_Nested_Feature_Attributions_with_Consistency_Property.pdf
# Downloaded ./arxiv_downloads\2406.13770v2.Elliptical_Attention.pdf
# Downloaded ./arxiv_downloads\2410.14574v1.MomentumSMoE__Integrating_Momentum_into_Sparse_Mixture_of_Experts.pdf
# Downloaded ./arxiv_downloads\2408.16667v1.Iterative_Graph_Alignment.pdf
# Downloaded ./arxiv_downloads\1704.07535v1.Abstract_Syntax_Networks_for_Code_Generation_and_Semantic_Parsing.pdf
# Downloaded ./arxiv_downloads\2110.15349v1.Learning_to_Ground_Multi_Agent_Communication_with_Autoencoders.pdf
# Downloaded ./arxiv_downloads\1704.07751v1.Fine_Grained_Entity_Typing_with_High_Multiplicity_Assignments.pdf
# Downloaded ./arxiv_downloads\2501.13333v1.AgentRec__Agent_Recommendation_Using_Sentence_Embeddings_Aligned_to_Human_Feedback.pdf
# Downloaded ./arxiv_downloads\2212.03869v1.Pre_Training_With_Scientific_Text_Improves_Educational_Question_Generation.pdf
# Downloaded ./arxiv_downloads\1902.02169v1.Learning_Taxonomies_of_Concepts_and_not_Words_using_Contextualized_Word_Representations__A_Position_Paper.pdf
# Downloaded ./arxiv_downloads\1802.09914v1.High_Dimensional_Vector_Semantics.pdf
# Downloaded ./arxiv_downloads\2411.01053v1.Contrasting_with_Symile__Simple_Model_Agnostic_Representation_Learning_for_Unlimited_Modalities.pdf
# Downloaded ./arxiv_downloads\1905.04835v2.Multi_Agent_Image_Classification_via_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\2006.07869v4.Benchmarking_Multi_Agent_Deep_Reinforcement_Learning_Algorithms_in_Cooperative_Tasks.pdf
# Downloaded ./arxiv_downloads\2409.13745v1.Context_Aware_Membership_Inference_Attacks_against_Pre_trained_Large_Language_Models.pdf
# Downloaded ./arxiv_downloads\2411.07464v2.BudgetMLAgent__A_Cost_Effective_LLM_Multi_Agent_system_for_Automating_Machine_Learning_Tasks.pdf
# Downloaded ./arxiv_downloads\1707.06480v1.Syllable_aware_Neural_Language_Models__A_Failure_to_Beat_Character_aware_Ones.pdf
# Downloaded ./arxiv_downloads\2006.07228v2.FedGAN__Federated_Generative_Adversarial_Networks_for_Distributed_Data.pdf
# Downloaded ./arxiv_downloads\1709.02797v1.On_the_exact_relationship_between_the_denoising_function_and_the_data_distribution.pdf
# Downloaded ./arxiv_downloads\1911.00997v2.Multiple_Futures_Prediction.pdf
# Downloaded ./arxiv_downloads\2501.01205v1.Harnessing_Multi_Agent_LLMs_for_Complex_Engineering_Problem_Solving__A_Framework_for_Senior_Design_Projects.pdf
# Downloaded ./arxiv_downloads\1406.3100v1.Learning_ELM_network_weights_using_linear_discriminant_analysis.pdf
# Downloaded ./arxiv_downloads\2311.00049v1.On_the_Kolmogorov_neural_networks.pdf
# Downloaded ./arxiv_downloads\2410.00079v1.Interactive_Speculative_Planning__Enhance_Agent_Efficiency_through_Co_design_of_System_and_User_Interface.pdf
# Downloaded ./arxiv_downloads\1808.02668v1.An_Occam_s_Razor_View_on_Learning_Audiovisual_Emotion_Recognition_with_Small_Training_Sets.pdf
# Downloaded ./arxiv_downloads\1705.10369v4.Emergent_Communication_in_a_Multi_Modal__Multi_Step_Referential_Game.pdf
# Downloaded ./arxiv_downloads\1805.11818v1.Visual_Referring_Expression_Recognition__What_Do_Systems_Actually_Learn_.pdf
# Downloaded ./arxiv_downloads\1911.13044v6.Learning_Structured_Representations_of_Spatial_and_Interactive_Dynamics_for_Trajectory_Prediction_in_Crowded_Scenes.pdf
# Downloaded ./arxiv_downloads\1910.13351v1.Admiring_the_Great_Mountain__A_Celebration_Special_Issue_in_Honor_of_Stephen_Grossbergs_80th_Birthday.pdf
# Downloaded ./arxiv_downloads\1308.2350v1.Learning_Features_and_their_Transformations_by_Spatial_and_Temporal_Spherical_Clustering.pdf
# Downloaded ./arxiv_downloads\1709.06620v1.Learning_of_Coordination_Policies_for_Robotic_Swarms.pdf
# Downloaded ./arxiv_downloads\2102.06358v1.Min_Max_Plus_Neural_Networks.pdf
# Downloaded ./arxiv_downloads\2009.03863v1.TanhSoft____a_family_of_activation_functions_combining_Tanh_and_Softplus.pdf
# Downloaded ./arxiv_downloads\2109.04386v4.ErfAct_and_Pserf__Non_monotonic_Smooth_Trainable_Activation_Functions.pdf
# Downloaded ./arxiv_downloads\2502.11271v1.OctoTools__An_Agentic_Framework_with_Extensible_Tools_for_Complex_Reasoning.pdf
# Downloaded ./arxiv_downloads\2206.04016v1.SYNERgy_between_SYNaptic_consolidation_and_Experience_Replay_for_general_continual_learning.pdf
# Downloaded ./arxiv_downloads\2203.01544v1.Rethinking_the_role_of_normalization_and_residual_blocks_for_spiking_neural_networks.pdf
# Downloaded ./arxiv_downloads\2106.09693v1.Orthogonal_Padé_Activation_Functions__Trainable_Activation_functions_for_smooth_and_faster_convergence_in_deep_networks.pdf
#  91%|█████████ | 453/500 [00:28<00:04, 10.34it/s]
# Downloaded ./arxiv_downloads\2301.05058v1.Sparse_Coding_in_a_Dual_Memory_System_for_Lifelong_Learning.pdf
# Downloaded ./arxiv_downloads\2302.07328v1.Hybrid_Spiking_Neural_Network_Fine_tuning_for_Hippocampus_Segmentation.pdf
#  91%|█████████ | 454/500 [00:28<00:04, 10.26it/s]
# Downloaded ./arxiv_downloads\2209.13400v2.Activation_Learning_by_Local_Competitions.pdf
# Downloaded ./arxiv_downloads\2304.10191v1.Efficient_Uncertainty_Estimation_in_Spiking_Neural_Networks_via_MC_dropout.pdf
# Downloaded ./arxiv_downloads\2307.16235v1.Spiking_Neural_Networks_and_Bio_Inspired_Supervised_Deep_Learning__A_Survey.pdf
# Downloaded ./arxiv_downloads\2304.06738v1.A_Study_of_Biologically_Plausible_Neural_Network__The_Role_and_Interactions_of_Brain_Inspired_Mechanisms_in_Continual_Learning.pdf
# Downloaded ./arxiv_downloads\2304.06767v4.RAFT__Reward_rAnked_FineTuning_for_Generative_Foundation_Model_Alignment.pdf
# Downloaded ./arxiv_downloads\2402.01782v1.Benchmarking_Spiking_Neural_Network_Learning_Methods_with_Varying_Locality.pdf
# Downloaded ./arxiv_downloads\2307.00039v1.Towards_Brain_Inspired_Design_for_Addressing_the_Shortcomings_of_ANNs.pdf
# Downloaded ./arxiv_downloads\2010.08262v5.Local_plasticity_rules_can_learn_deep_representations_using_self_supervised_contrastive_predictions.pdf
# Downloaded ./arxiv_downloads\2407.08704v1.Towards_Efficient_Deployment_of_Hybrid_SNNs_on_Neuromorphic_and_Edge_AI_Hardware.pdf
# Downloaded ./arxiv_downloads\2407.01606v1.On_Discrete_Prompt_Optimization_for_Diffusion_Models.pdf
# Downloaded ./arxiv_downloads\2307.16236v1.Synaptic_Plasticity_Models_and_Bio_Inspired_Unsupervised_Deep_Learning__A_Survey.pdf
# Downloaded ./arxiv_downloads\2502.10421v1.DRiVE__Dynamic_Recognition_in_VEhicles_using_snnTorch.pdf
# Downloaded ./arxiv_downloads\2403.15974v1.CBGT_Net__A_Neuromimetic_Architecture_for_Robust_Classification_of_Streaming_Data.pdf
# Downloaded ./arxiv_downloads\1703.03864v2.Evolution_Strategies_as_a_Scalable_Alternative_to_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\1709.05870v1.ZhuSuan__A_Library_for_Bayesian_Deep_Learning.pdf
# Downloaded ./arxiv_downloads\2403.00865v1.Fast_and_Efficient_Local_Search_for_Genetic_Programming_Based_Loss_Function_Learning.pdf
# Downloaded ./arxiv_downloads\1801.03143v1.Comparing_heterogeneous_entities_using_artificial_neural_networks_of_trainable_weighted_structural_components_and_machine_learned_activation_functions.pdf
# Downloaded ./arxiv_downloads\2205.07076v1.Spiking_Approximations_of_the_MaxPooling_Operation_in_Deep_SNNs.pdf
# Downloaded ./arxiv_downloads\2009.08801v1.SciBERT_based_Semantification_of_Bioassays_in_the_Open_Research_Knowledge_Graph.pdf
# Downloaded ./arxiv_downloads\1710.10704v3.Training_Probabilistic_Spiking_Neural_Networks_with_First_to_spike_Decoding.pdf
# Downloaded ./arxiv_downloads\2407.07133v1.Neuromimetic_metaplasticity_for_adaptive_continual_learning.pdf
# Downloaded ./arxiv_downloads\1804.01756v3.The_Kanerva_Machine__A_Generative_Distributed_Memory.pdf
# Downloaded ./arxiv_downloads\1606.02396v1.Deep_Successor_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\1804.01712v1.Variational_Rejection_Sampling.pdf
# Downloaded ./arxiv_downloads\1711.03640v1.Stochastic_Deep_Learning_in_Memristive_Networks.pdf
# Downloaded ./arxiv_downloads\1705.10119v3.Kernel_Implicit_Variational_Inference.pdf
#  96%|█████████▌| 481/500 [00:34<00:02,  8.25it/s]
# Downloaded ./arxiv_downloads\2409.15375v1.DS2TA__Denoising_Spiking_Transformer_with_Attenuated_Spatiotemporal_Attention.pdf
# Downloaded ./arxiv_downloads\1710.05468v9.Generalization_in_Deep_Learning.pdf
# Downloaded ./arxiv_downloads\1802.07426v3.Generalization_in_Machine_Learning_via_Analytical_Learning_Theory.pdf
# Downloaded ./arxiv_downloads\2102.13388v1.Zoetrope_Genetic_Programming_for_Regression.pdf
# Downloaded ./arxiv_downloads\2008.00386v1.Bayesian_Optimization_for_Selecting_Efficient_Machine_Learning_Models.pdf
# Downloaded ./arxiv_downloads\2011.05605v2.Decentralized_Motion_Planning_for_Multi_Robot_Navigation_using_Deep_Reinforcement_Learning.pdf
# Downloaded ./arxiv_downloads\1805.09692v2.Been_There__Done_That__Meta_Learning_with_Episodic_Recall.pdf
# Downloaded ./arxiv_downloads\1504.01483v1.Transferring_Knowledge_from_a_RNN_to_a_DNN.pdf
# Downloaded ./arxiv_downloads\1904.02338v2.Consistency_by_Agreement_in_Zero_shot_Neural_Machine_Translation.pdf
# Downloaded ./arxiv_downloads\2402.10210v1.Self_Play_Fine_Tuning_of_Diffusion_Models_for_Text_to_Image_Generation.pdf
# Downloaded ./arxiv_downloads\1912.10729v1.TextNAS__A_Neural_Architecture_Search_Space_tailored_for_Text_Representation.pdf
# Downloaded ./arxiv_downloads\1909.02950v2.Supervised_Multimodal_Bitransformers_for_Classifying_Images_and_Text.pdf
# Downloaded ./arxiv_downloads\1810.12754v1.Recurrent_Attention_Unit.pdf
# Downloaded ./arxiv_downloads\1409.2944v2.Collaborative_Deep_Learning_for_Recommender_Systems.pdf
# Downloaded ./arxiv_downloads\1901.09821v1.Squeezed_Very_Deep_Convolutional_Neural_Networks_for_Text_Classification.pdf
# Downloaded ./arxiv_downloads\1711.01577v3.Wider_and_Deeper__Cheaper_and_Faster__Tensorized_LSTMs_for_Sequence_Learning.pdf
# Downloaded ./arxiv_downloads\1612.06212v1.A_recurrent_neural_network_without_chaos.pdf
# Downloaded ./arxiv_downloads\2404.03900v1.Nonparametric_Modern_Hopfield_Models.pdf
# 100%|█████████▉| 498/500 [00:37<00:00,  7.71it/s]
# Downloaded ./arxiv_downloads\1909.10447v1.On_Model_Stability_as_a_Function_of_Random_Seed.pdf
# Downloaded ./arxiv_downloads\2412.05255v1.TeamCraft__A_Benchmark_for_Multi_Modal_Multi_Agent_Systems_in_Minecraft.pdf
# 100%|██████████| 500/500 [00:37<00:00, 13.23it/s]
# Downloaded ./arxiv_downloads\1706.00290v1.Transfer_Learning_for_Speech_Recognition_on_a_Budget.pdf
# All downloads completed.
