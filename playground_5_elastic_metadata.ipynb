# %% [markdown]
# # 1. Download arXiv metadata in bulk
# from [kaggle](https://www.kaggle.com/datasets/Cornell-University/arxiv/data) and save as `./arxiv_metadata/arxiv-metadata-oai-snapshot.json`

# %% [markdown]
# # 2. Setup of Elastic search (on Windows)
#
# 1. install Docker
#
# 2. open WSL shell in this directory and execute:
#
#     ```bash
#     curl -fsSL https://elastic.co/start-local | sh
#     ```
# ---
#
# After running the script, you can access Elastic services at the following endpoints:
#
# - Elasticsearch: http://localhost:9200
# - Kibana: http://localhost:5601
#
# The script generates a random password for the `elastic` user, and an API key, stored in the [.env file](./elastic-start-local/.env).
#
# ---

# %% [markdown]
# # 3. import downloaded arxiv metadata files

# %%
metadata_file = './arxiv_metadata/arxiv-metadata-oai-snapshot.json'

# %%
import json
from rolling.pdf import clean_text

def reader():
    with open(metadata_file, 'r', encoding='utf-8') as f:
        for line in f:
            entry = json.loads(line)
            
            entry['title'] = clean_text(entry['title'])
            entry['abstract'] = clean_text(entry['abstract'])

            if 'categories' in entry:
                entry['categories'] = [
                    {
                        "category": c
                    } for c in entry['categories'].split(' ')
                ]
            if 'authors_parsed' in entry:
                entry['authors_parsed'] = [
                    {
                        "author": c
                    } for c in entry['authors_parsed']
                ]

            yield entry

line_iterator = reader()

# %%
from rolling.embedding import GTEEmbeddingModel
model = GTEEmbeddingModel()

# %%
def process_embeddings(entries:list[dict]):
    texts = [
        f'{e['title']}\n{e['abstract']}'
        for e in entries
    ]
    embeddings = model.encode(texts)
    for emb, entr in zip(embeddings, entries):
        entr['embedding'] = emb

    return entries

# %%
index_name = "arxiv"
def prepare_data_for_insert(objects:list[dict]):
    return [
        {
            "_index": index_name,
            "_id": o['id'],
            "_source": o,
        } for o in objects
    ]

# %%
def bulk_provider():
    counter = 0
    while True:
        # load data
        last_entry = False
        data = []        
        try:
            for _ in range(32):
                data.append(next(line_iterator))
        except StopIteration:
            last_entry = True

        data = process_embeddings(data)
        data = prepare_data_for_insert(data)
        
        for d in data:
            counter += 1
            if counter % 10000 == 0:
                print(f'Yielded {counter} results...')
            yield d

        if last_entry:
            break

provider = bulk_provider()

# %%
from elasticsearch import Elasticsearch
client = Elasticsearch("http://localhost:9200/", api_key="a1VxLUZaWUJ6Q1VRYXlSWTJSX2U6RWx3X0xQbXZURnlsNGU5UmNFeWZhZw==") # localhost

# %%
if not client.indices.exists(index=index_name):
    client.indices.create(index=index_name)

# %%
# Delete
if client.indices.exists(index=index_name):
    client.indices.delete(index=index_name)

# %%
from elasticsearch import helpers
from elasticsearch.helpers import BulkIndexError

try:
    helpers.bulk(client, provider)
except BulkIndexError as e:
    print("Bulk indexing failed with the following errors:")
    for error in e.errors:
        print(error)
# Out:
# Yielded 10000 results...
# Yielded 20000 results...
# Yielded 30000 results...
# Yielded 40000 results...
# Yielded 50000 results...
# Yielded 60000 results...
# Yielded 70000 results...
# Yielded 80000 results...
# Yielded 90000 results...
# Yielded 100000 results...
# Yielded 110000 results...
# Yielded 120000 results...
# Yielded 130000 results...
# Yielded 140000 results...
# Yielded 150000 results...
# Yielded 160000 results...
# Yielded 170000 results...
# Yielded 180000 results...
# Yielded 190000 results...
# Yielded 200000 results...
# Yielded 210000 results...
# Yielded 220000 results...
# Yielded 230000 results...
# Yielded 240000 results...
# Yielded 250000 results...
# Yielded 260000 results...
# Yielded 270000 results...
# Yielded 280000 results...
# Yielded 290000 results...
# Yielded 300000 results...
# Yielded 310000 results...
# Yielded 320000 results...
# Yielded 330000 results...
# Yielded 340000 results...
# Yielded 350000 results...
# Yielded 360000 results...
# Yielded 370000 results...
# Yielded 380000 results...
# Yielded 390000 results...
# Yielded 400000 results...
# Yielded 410000 results...
# Yielded 420000 results...
# Yielded 430000 results...
# Yielded 440000 results...
# Yielded 450000 results...
# Yielded 460000 results...
# Yielded 470000 results...
# Yielded 480000 results...
# Yielded 490000 results...
# Yielded 500000 results...
# Yielded 510000 results...
# Yielded 520000 results...
# Yielded 530000 results...
# Yielded 540000 results...
# Yielded 550000 results...
# Yielded 560000 results...
# Yielded 570000 results...
# Yielded 580000 results...
# Yielded 590000 results...
# Yielded 600000 results...
# Yielded 610000 results...
# Yielded 620000 results...
# Yielded 630000 results...
# Yielded 640000 results...
# Yielded 650000 results...
# Yielded 660000 results...
# Yielded 670000 results...
# Yielded 680000 results...
# Yielded 690000 results...
# Yielded 700000 results...
# Yielded 710000 results...
# Yielded 720000 results...
# Yielded 730000 results...
# Yielded 740000 results...
# Yielded 750000 results...
# Yielded 760000 results...
# Yielded 770000 results...
# Yielded 780000 results...
# Yielded 790000 results...
# Yielded 800000 results...
# Yielded 810000 results...
# Yielded 820000 results...
# Yielded 830000 results...
# Yielded 840000 results...
# Yielded 850000 results...
# Yielded 860000 results...
# Yielded 870000 results...
# Yielded 880000 results...
# Yielded 890000 results...
# Yielded 900000 results...
# Yielded 910000 results...
# Yielded 920000 results...
# Yielded 930000 results...
# Yielded 940000 results...
# Yielded 950000 results...
# Yielded 960000 results...
# Yielded 970000 results...
# Yielded 980000 results...
# Yielded 990000 results...
# Yielded 1000000 results...
# Yielded 1010000 results...
# Yielded 1020000 results...
# Yielded 1030000 results...
# Yielded 1040000 results...
# Yielded 1050000 results...
# Yielded 1060000 results...
# Yielded 1070000 results...
# Yielded 1080000 results...
# Yielded 1090000 results...
# Yielded 1100000 results...
# Yielded 1110000 results...
# Yielded 1120000 results...
# Yielded 1130000 results...
# Yielded 1140000 results...
# Yielded 1150000 results...
# Yielded 1160000 results...
# Yielded 1170000 results...
# Yielded 1180000 results...
# Yielded 1190000 results...
# Yielded 1200000 results...
# Yielded 1210000 results...
# Yielded 1220000 results...
# Yielded 1230000 results...
# Yielded 1240000 results...
# Yielded 1250000 results...
# Yielded 1260000 results...
# Yielded 1270000 results...
# Yielded 1280000 results...
# Yielded 1290000 results...
# Yielded 1300000 results...
# Yielded 1310000 results...
# Yielded 1320000 results...
# Yielded 1330000 results...
# Yielded 1340000 results...
# Yielded 1350000 results...
# Yielded 1360000 results...
# Yielded 1370000 results...
# Yielded 1380000 results...
# Yielded 1390000 results...
# Yielded 1400000 results...
# Yielded 1410000 results...
# Yielded 1420000 results...
# Yielded 1430000 results...
# Yielded 1440000 results...
# Yielded 1450000 results...
# Yielded 1460000 results...
# Yielded 1470000 results...
# Yielded 1480000 results...
# Yielded 1490000 results...
# Yielded 1500000 results...
# Yielded 1510000 results...
# Yielded 1520000 results...
# Yielded 1530000 results...
# Yielded 1540000 results...
# Yielded 1550000 results...
# Yielded 1560000 results...
# Yielded 1570000 results...
# Yielded 1580000 results...
# Yielded 1590000 results...
# Yielded 1600000 results...
# Yielded 1610000 results...
# Yielded 1620000 results...
# Yielded 1630000 results...
# Yielded 1640000 results...
# Yielded 1650000 results...
# Yielded 1660000 results...
# Yielded 1670000 results...
# Yielded 1680000 results...
# Yielded 1690000 results...
# Yielded 1700000 results...
# Yielded 1710000 results...
# Yielded 1720000 results...
# Yielded 1730000 results...
# Yielded 1740000 results...
# Yielded 1750000 results...
# Yielded 1760000 results...
# Yielded 1770000 results...
# Yielded 1780000 results...
# Yielded 1790000 results...
# Yielded 1800000 results...
# Yielded 1810000 results...
# Yielded 1820000 results...
# Yielded 1830000 results...
# Yielded 1840000 results...
# Yielded 1850000 results...
# Yielded 1860000 results...
# Yielded 1870000 results...
# Yielded 1880000 results...
# Yielded 1890000 results...
# Yielded 1900000 results...
# Yielded 1910000 results...
# Yielded 1920000 results...
# Yielded 1930000 results...
# Yielded 1940000 results...
# Yielded 1950000 results...
# Yielded 1960000 results...
# Yielded 1970000 results...
# Yielded 1980000 results...
# Yielded 1990000 results...
# Yielded 2000000 results...
# Yielded 2010000 results...
# Yielded 2020000 results...
# Yielded 2030000 results...
# Yielded 2040000 results...
# Yielded 2050000 results...
# Yielded 2060000 results...
# Yielded 2070000 results...
# Yielded 2080000 results...
# Yielded 2090000 results...
# Yielded 2100000 results...
# Yielded 2110000 results...
# Yielded 2120000 results...
# Yielded 2130000 results...
# Yielded 2140000 results...
# Yielded 2150000 results...
# Yielded 2160000 results...
# Yielded 2170000 results...
# Yielded 2180000 results...
# Yielded 2190000 results...
# Yielded 2200000 results...
# Yielded 2210000 results...
# Yielded 2220000 results...
# Yielded 2230000 results...
# Yielded 2240000 results...
# Yielded 2250000 results...
# Yielded 2260000 results...
# Yielded 2270000 results...
# Yielded 2280000 results...
# Yielded 2290000 results...
# Yielded 2300000 results...
# Yielded 2310000 results...
# Yielded 2320000 results...
# Yielded 2330000 results...
# Yielded 2340000 results...
# Yielded 2350000 results...
# Yielded 2360000 results...
# Yielded 2370000 results...
# Yielded 2380000 results...
# Yielded 2390000 results...
# Yielded 2400000 results...
# Yielded 2410000 results...
# Yielded 2420000 results...
# Yielded 2430000 results...
# Yielded 2440000 results...
# Yielded 2450000 results...
# Yielded 2460000 results...
# Yielded 2470000 results...
# Yielded 2480000 results...
# Yielded 2490000 results...
# Yielded 2500000 results...
# Yielded 2510000 results...
# Yielded 2520000 results...
# Yielded 2530000 results...
# Yielded 2540000 results...
# Yielded 2550000 results...
# Yielded 2560000 results...
# Yielded 2570000 results...
# Yielded 2580000 results...
# Yielded 2590000 results...
# Yielded 2600000 results...
# Yielded 2610000 results...
# Yielded 2620000 results...
# Yielded 2630000 results...
# Yielded 2640000 results...
# Yielded 2650000 results...
# Yielded 2660000 results...
#          1.7181e-02, -6.1913e-03,  6.8436e-03,  9.5444e-03, -4.5349e-02,
#          3.2104e-02, -2.3560e-02, -1.7548e-02,  4.6967e-02,  4.7333e-02,
#          2.5574e-02, -3.9612e-02,  4.6478e-02, -4.8981e-02, -4.7607e-02,
#          4.3396e-02,  3.2654e-02, -1.4472e-04,  1.3985e-02,  5.7739e-02,
#          1.1925e-02,  1.0124e-02, -3.0151e-02,  2.2079e-02, -2.4948e-02,
#          5.9929e-03,  1.6830e-02, -1.7227e-02,  4.3823e-02,  1.6418e-02,
#         -8.4961e-02, -1.9791e-02, -6.9641e-02,  3.4695e-03, -9.5673e-03,
#          3.2654e-02,  5.6519e-02,  1.2455e-03,  7.0381e-03,  2.7733e-03,
#          4.7333e-02, -6.3858e-03,  9.8495e-03,  1.8295e-02,  2.4887e-02,
#         -1.2337e-02,  2.3468e-02, -5.3024e-04,  1.5839e-02,  3.3783e-02,
#         -2.9099e-02,  1.6983e-02,  7.1602e-03,  2.1912e-02, -1.6632e-02,
#         -6.8909e-02, -1.0628e-02, -1.1192e-02, -1.4963e-03,  4.7791e-02,
#          7.8888e-03, -2.2293e-02, -1.1421e-02,  3.4866e-03, -3.3569e-02,
#          2.0050e-02,  6.0844e-03,  6.6467e-02, -2.6062e-02,  2.5833e-02,
#         -1.2283e-02,  5.3223e-02,  1.1513e-02,  8.1024e-03,  7.8430e-03,
#          7.2449e-02, -2.2675e-02, -5.4741e-03, -7.7553e-03, -6.2042e-02,
#          4.6577e-03,  4.4525e-02,  3.2837e-02,  1.5617e-02,  2.8900e-02,
#         -4.1138e-02,  2.3468e-02, -2.4811e-02,  5.4169e-03,  1.5839e-02,
#          9.6283e-03, -2.8412e-02, -3.7445e-02, -3.6987e-02,  1.3714e-03,
#          5.3978e-03,  5.1575e-03, -1.1116e-02,  4.6173e-02, -2.7046e-03,
#          9.5520e-03,  2.5528e-02,  1.3733e-02,  3.7140e-02,  4.8523e-02,
#         -3.5767e-02,  1.3710e-02, -5.2002e-02, -5.1910e-02, -4.6921e-03,
#          8.4000e-03, -3.3295e-02, -2.0721e-02, -6.0394e-02, -8.3389e-03,
#          4.0283e-02, -6.9763e-02,  3.3936e-02], dtype=float16))

# %%
response = client.search(
    index=index_name,
    query={
        "knn": {
            "field": "embedding",
            "query_vector": emb
        }
    }
)

# %%
for e in response['hits']['hits']:
        print(f'{e["_score"]:.5f}: {e["_source"]["title"]}')
# Out:
# 0.87402: Large Language Model-Driven Cross-Domain Orchestration Using Multi-Agent Workflow
# 0.87323: Towards Collaborative Question Answering: A Preliminary Study
# 0.86929: AutoAgents: A Framework for Automatic Agent Generation
# 0.86870: Automated Task-Time Interventions to Improve Teamwork using Imitation Learning
# 0.86700: A Cordial Sync: Going Beyond Marginal Policies for Multi-Agent Embodied Tasks
# 0.86674: Autonomous Agents for Collaborative Task under Information Asymmetry
# 0.86560: Coordinating metaheuristic agents with swarm intelligence
# 0.86504: BMW Agents -- A Framework For Task Automation Through Multi-Agent Collaboration
# 0.86449: Iris: A Conversational Agent for Complex Tasks
# 0.86244: Magentic-One: A Generalist Multi-Agent System for Solving Complex Tasks
